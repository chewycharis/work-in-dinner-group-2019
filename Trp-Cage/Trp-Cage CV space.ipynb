# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Target Points for ABMD Simulations**

# %%
xy_rmsd=np.array([[1,0.25],[2,0.25],[3,0.25],[4,0.25],[5,0.25],[6,0.25], [7,0.25],[1,0.5],[2,0.5],[3,0.5],[4,0.5],[5,0.5],[6,0.5], [7,0.5] , [2,0.75],[3,0.75],[4,0.75],[5,0.75],[6,0.75],[5.5,1], [5.5,1.25], [5.5,1.5], [5.5,1.75]])
plt.scatter(xy_rmsd[:,0],xy_rmsd[:,1]);
plt.xlabel("C-alpha RMSD (Angstrom)")
plt.ylabel("helix RMSD (Angstrom)")
# Out:
# Text(0, 0.5, 'helix RMSD (Angstrom)')

# %%
end_to_end_distance=np.arange(5,40,5)
molecular_chirality=np.arange(-1,1.25,0.25)
x,y=np.meshgrid(end_to_end_distance, molecular_chirality)
new_list=[]
for i in range(9):
    for j in range(7):
        new_list.append([x[i,j],y[i,j]])

new_list=np.asarray(new_list)
plt.scatter(new_list[:,0],new_list[:,1])
plt.xlabel("end to end distance (Angstrom)")
plt.ylabel("molecular chirality")
# Out:
# Text(0, 0.5, 'molecular chirality')

# %%
molecular_chirality=np.arange(-1,1.25,0.25)
rmsd=np.arange(1,8,1)
x,y=np.meshgrid(rmsd,molecular_chirality)
new_list=[]
for i in range(9):
    for j in range(7):
        new_list.append([x[i,j],y[i,j]])

new_list=np.asarray(new_list)
plt.scatter(x,y)
plt.xlabel("C-alpha RMSD (Angstrom)")
plt.ylabel("molecular chirality")
# Out:
# Text(0, 0.5, 'molecular chirality')

# %%
molecular_chirality=np.arange(-0.75,1,0.25)
helix=np.arange(0.25,2,0.25)
x,y=np.meshgrid(helix,molecular_chirality)
plt.scatter(x,y)
plt.xlabel("Helix C-alpha RMSD (Angstrom)")
plt.ylabel("molecular chirality")
# Out:
# Text(0, 0.5, 'molecular chirality')

# %%
end_to_end_distance=np.arange(5,40,5)
helix=np.arange(0.25,2,0.25)
x,y=np.meshgrid(helix,end_to_end_distance)
plt.scatter(x,y)
plt.xlabel("Helix C-alpha RMSD (Angstrom)")
plt.ylabel("End to End Distance (Angstrom)")
# Out:
# Text(0, 0.5, 'End to End Distance (Angstrom)')

# %%
np.linspace(5,35,5)
# Out:
# array([ 5. , 12.5, 20. , 27.5, 35. ])

# %%
k=0.5
print(str(k))
# Out:
# 0.5

# %%
launch_abmd_end_distance_rmsd_calpha.py
